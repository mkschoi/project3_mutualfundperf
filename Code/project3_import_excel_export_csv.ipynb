# %% [markdown]
# ### 1. Import excel files containing raw mutual fund data

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('../Data/US_mutual_fund_data.xlsx')
df2 = pd.read_excel('../Data/US_mutual_fund_data2.xlsx')

# %%
df1.head()
# Out:
#    Unnamed: 0                      Unnamed: 1  Unnamed: 2  \
# 0         NaN  1290 GAMCO Small/Mid Cap Value         NaN
# 1         NaN                             NaN         NaN
# 2         NaN                             NaN         NaN
# 3         NaN                             NaN         NaN
# 4         NaN                             NaN         NaN
#
#                        Unnamed: 3  Unnamed: 4 morningstar_risk  Unnamed: 6  \
# 0                   Above Average         NaN               --         NaN
# 1  1290 GAMCO Small/Mid Cap Value         NaN    Above Average         NaN
# 2  1290 GAMCO Small/Mid Cap Value         NaN    Above Average         NaN
# 3  1290 GAMCO Small/Mid Cap Value         NaN    Above Average         NaN
# 4                  13D Activist A         NaN    Above Average         NaN
#
#   avg_moat_rating  Unnamed: 8 morningstar_sustainability_rating  ...  \
# 0               2         NaN                              5.33  ...
# ...

# %% [markdown]
# ### 2. Align the columns and drop empty rows

# %%
df1.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df1.drop(df1[df1.isnull().all(1)].index, inplace=True)

# %%
df1
# Out:
#                           Unnamed: 1  Unnamed: 2  \
# 0     1290 GAMCO Small/Mid Cap Value         NaN
# 1                                NaN         NaN
# 2                                NaN         NaN
# 3                                NaN         NaN
# 4                                NaN         NaN
# ...                              ...         ...
# 6644                             NaN         NaN
# 6645                             NaN         NaN
# 6646                             NaN         NaN
# 6647                             NaN         NaN
# 6648                             NaN         NaN
#
#                           Unnamed: 3  Unnamed: 4 morningstar_risk  Unnamed: 6  \
# 0                      Above Average         NaN               --         NaN
# 1     1290 GAMCO Small/Mid Cap Value         NaN    Above Average         NaN
# 2     1290 GAMCO Small/Mid Cap Value         NaN    Above Average         NaN
# ...

# %%
df2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df2.drop(df2[df2.isnull().all(1)].index, inplace=True)

# %%
df2
# Out:
#                           Unnamed: 1  Unnamed: 2  \
# 0     1290 GAMCO Small/Mid Cap Value         NaN
# 1                                NaN         NaN
# 2                                NaN         NaN
# 3                                NaN         NaN
# 4                                NaN         NaN
# ...                              ...         ...
# 6554                             NaN         NaN
# 6555                             NaN         NaN
# 6556                             NaN         NaN
# 6557                             NaN         NaN
# 6558                             NaN         NaN
#
#                           Unnamed: 3  Unnamed: 4 debt_to_capital_last_year  \
# 0                              46.75         NaN                       145
# 1     1290 GAMCO Small/Mid Cap Value         NaN                     46.75
# 2     1290 GAMCO Small/Mid Cap Value         NaN                     46.75
# ...

# %%
df1[df1['Unnamed: 1'].notnull()] = df1[df1['Unnamed: 1'].notnull()].shift(1, axis=1)

# %%
df1.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', 
          'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22'], axis=1, inplace=True)

# %%
df1.rename(columns={'Unnamed: 3':'fund_name'}, inplace=True)

# %%
df1
# Out:
#                            fund_name morningstar_risk avg_moat_rating  \
# 0     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 1     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 2     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 3     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 4                     13D Activist A    Above Average              --
# ...                              ...              ...             ...
# 6644  Zevenbergen Genea Institutiona             High            2.77
# 6645      Zevenbergen Genea Investor             High            2.77
# 6646  Zevenbergen Growth Institution             High           3.028
# 6647     Zevenbergen Growth Investor             High           3.028
# 6648  Ziegler Piermont Small Cap Val               --              --
#
#      morningstar_sustainability_rating three_year_return  \
# 0                                    2              5.33
# ...

# %%
df2[df2['Unnamed: 1'].notnull()] = df2[df2['Unnamed: 1'].notnull()].shift(1, axis=1)

# %%
df2.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', 
          'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22'], axis=1, inplace=True)

# %%
df2.rename(columns={'Unnamed: 3':'fund_name'}, inplace=True)

# %%
df1.reset_index(inplace=True, drop=True)

# %%
df2.reset_index(inplace=True, drop=True)

# %%
df1
# Out:
#                            fund_name morningstar_risk avg_moat_rating  \
# 0     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 1     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 2     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 3     1290 GAMCO Small/Mid Cap Value    Above Average              --
# 4                     13D Activist A    Above Average              --
# ...                              ...              ...             ...
# 6516  Zevenbergen Genea Institutiona             High            2.77
# 6517      Zevenbergen Genea Investor             High            2.77
# 6518  Zevenbergen Growth Institution             High           3.028
# 6519     Zevenbergen Growth Investor             High           3.028
# 6520  Ziegler Piermont Small Cap Val               --              --
#
#      morningstar_sustainability_rating three_year_return  \
# 0                                    2              5.33
# ...

# %%
df2
# Out:
#                            fund_name debt_to_capital_last_year  \
# 0     1290 GAMCO Small/Mid Cap Value                     46.75
# 1     1290 GAMCO Small/Mid Cap Value                     46.75
# 2     1290 GAMCO Small/Mid Cap Value                     46.75
# 3     1290 GAMCO Small/Mid Cap Value                     46.75
# 4                     13D Activist A                     53.74
# ...                              ...                       ...
# 6516  Zevenbergen Genea Institutiona                     38.04
# 6517      Zevenbergen Genea Investor                     38.04
# 6518  Zevenbergen Growth Institution                     39.47
# 6519     Zevenbergen Growth Investor                     39.47
# 6520  Ziegler Piermont Small Cap Val                     39.12
#
#      no_of_holdings_in_portfolio pct_assets_in_top10_holdings turnover  \
# 0                            145                        24.27       19
# ...

# %% [markdown]
# ### 3. Add Mutual Fund Tickers

# %%
df3 = pd.read_excel('../Data/mutual_fund_tickers.xlsx')

# %%
df4 = pd.concat([df3,df1],axis=1)

# %%
df4.drop('fund_name',axis=1,inplace=True)

# %%
df4
# Out:
#      ticker morningstar_risk avg_moat_rating  \
# 0     TNVAX    Above Average              --
# 1     TNVIX    Above Average              --
# 2     TNVRX    Above Average              --
# 3     TNVCX    Above Average              --
# 4     DDDAX    Above Average              --
# ...     ...              ...             ...
# 6516  ZVGIX             High            2.77
# 6517  ZVGNX             High            2.77
# 6518  ZVNIX             High           3.028
# 6519  ZVNBX             High           3.028
# 6520  ZPSVX               --              --
#
#      morningstar_sustainability_rating three_year_return  \
# 0                                    2              5.33
# 1                                    2              5.58
# 2                                    2              5.06
# 3                                    2              5.58
# 4                                    2              8.82
# ...                                ...               ...
# ...

# %%
df5 = pd.concat([df3,df2],axis=1)

# %%
df5.drop('fund_name',axis=1,inplace=True)

# %%
df5
# Out:
#      ticker debt_to_capital_last_year no_of_holdings_in_portfolio  \
# 0     TNVAX                     46.75                         145
# 1     TNVIX                     46.75                         145
# 2     TNVRX                     46.75                         145
# 3     TNVCX                     46.75                         145
# 4     DDDAX                     53.74                          33
# ...     ...                       ...                         ...
# 6516  ZVGIX                     38.04                          32
# 6517  ZVGNX                     38.04                          32
# 6518  ZVNIX                     39.47                          36
# 6519  ZVNBX                     39.47                          36
# 6520  ZPSVX                     39.12                         114
#
#      pct_assets_in_top10_holdings turnover avg_manager_tenure expense_ratio  \
# 0                           24.27       19                  6          1.25
# ...

# %% [markdown]
# ### 4. Export the dataframes as CSV files

# %%
df4.to_csv('../Data/US_mutual_fund_data_left.csv', index=False)
df5.to_csv('../Data/US_mutual_fund_data_right.csv', index=False)
